# %% [markdown]
# ## Import required libraries

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2021, 5, 24)

# %%
numpy
tensorflow 
keras

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
os.chdir("/Users/aniketbhalerao/Documents/public")
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# %% [markdown]
# ## Store data, labels in the list

# %%
data = []
labels = []
# We have 3 Classes
classes = 3
cur_path = os.getcwd()

# %%
cur_path
# Out:
# '/Users/aniketbhalerao/Documents/public'

# %%
path = os.path.join(cur_path)
path
# Out:
# '/Users/aniketbhalerao/Documents/public'

# %%
images = os.listdir(path)
images
# Out:
# ['.DS_Store', 'test', 'train', 'validation']

# %% [markdown]
# ## Preprocess the images

# %%
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)
    for a in images:
        try:
            image = Image.open(path + '/'+ a)
            image = image.resize((128,128))
            image = np.array(image)
            if image.shape == (128,128,3):
                data.append(image)
                labels.append(i)
        except Exception as e:
            print(e)
# Out:
# cannot identify image file '/Users/aniketbhalerao/Documents/public/train/2/.DS_Store'

# %% [markdown]
# ## Converting lists into numpy arrays

# %% [markdown]
# ## Save Labels & Data for future use

# %%
np.save("/Users/aniketbhalerao/Documents/training/data",data)
np.save("/Users/aniketbhalerao/Documents/training/target",labels)

# %% [markdown]
# ## Load data & Labels

# %%
data  =np.load("/Users/aniketbhalerao/Documents/training/data.npy")
labels=np.load("/Users/aniketbhalerao/Documents/training/target.npy")

# %%
print(data.shape, labels.shape)
# Out:
# (476, 128, 128, 3) (476,)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (380, 128, 128, 3) (96, 128, 128, 3) (380,) (96,)

# %% [markdown]
# ## Convert labels to onehot encoding

# %%
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %% [markdown]
# ## Now it's time to build the model

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 124, 124, 32)      2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 120, 32)      25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 60, 60, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 58, 58, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 64)        0
# ...

# %%
#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 20
history = model.fit(X_train, y_train, batch_size=8, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 48/48 [==============================] - 17s 341ms/step - loss: 25.5972 - accuracy: 0.3824 - val_loss: 1.0997 - val_accuracy: 0.2604
# Epoch 2/20
# 48/48 [==============================] - 16s 333ms/step - loss: 1.0975 - accuracy: 0.3518 - val_loss: 1.1050 - val_accuracy: 0.2604
# Epoch 3/20
# 48/48 [==============================] - 16s 334ms/step - loss: 1.1021 - accuracy: 0.3365 - val_loss: 1.1044 - val_accuracy: 0.2604
# Epoch 4/20
# 48/48 [==============================] - 17s 352ms/step - loss: 1.0950 - accuracy: 0.3248 - val_loss: 1.0847 - val_accuracy: 0.3229
# Epoch 5/20
# 48/48 [==============================] - 17s 359ms/step - loss: 1.0606 - accuracy: 0.4362 - val_loss: 0.9972 - val_accuracy: 0.4062
# Epoch 6/20
# 48/48 [==============================] - 22s 456ms/step - loss: 1.0037 - accuracy: 0.4721 - val_loss: 1.0919 - val_accuracy: 0.3438
# Epoch 7/20
# ...

# %%
# accuracy 
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# Loss
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Save the model

# %%
model.save("/Users/aniketbhalerao/Documents/training/public_model2.h5")

# %% [markdown]
# ## Load the Model

# %%
from keras.models import load_model
model = load_model('/Users/aniketbhalerao/Documents/training/public_model1.h5')

# %%
classes = { 0:'Electricity',
            1:'Garbage', 
            2:'Potholes'
          }

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((128,128))
    data.append(np.array(image))
    X_test=np.array(data)
    Y_pred = model.predict_classes(X_test)
    pred = model.predict(X_test)
    return image,Y_pred, pred

# %%
plot,prediction, pred = test_on_img(f"/Users/aniketbhalerao/Documents/public/validation/garbage/111.jpg")
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Garbage

# %%
pred
# Out:
# array([[0.35305375, 0.35088617, 0.2960601 ]], dtype=float32)

# %% [markdown]
# ### task

# %%
88/100
# Out:
# 0.88

# %%
1 overall accuracy
2 electricity accuracy
3 garbage accuracy
4 potholes accuracy
